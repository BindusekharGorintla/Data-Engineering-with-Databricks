-- %% [markdown]
-- <div style="text-align: center; line-height: 0; padding-top: 9px;">
--   <img
--     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
--     alt="Databricks Learning"
--   >
-- </div>

-- %% [markdown]
-- # 1.2 Lab - Use Unity Catalog to Locate and Inspect Datasets
--
-- In this lab you will explore your environment.

-- %% [markdown]
-- ## REQUIRED - SELECT A SHARED SQL WAREHOUSE
--
-- Before executing cells in this notebook, please select the **SHARED SQL WAREHOUSE** in the lab. Follow these steps:
--
-- 1. Navigate to the top-right of this notebook and click the drop-down to select compute (it might say **Connect**). Complete one of the following below:
--
--    a. Under **Recent resources**, check to see if you have a **shared_warehouse SQL**. If you do, select it.
--
--    b. If you do not have a **shared_warehouse** under **Recent resources**, complete the following:
--
--     - In the same drop-down, select **More**.
--
--     - Then select the **SQL Warehouse** button.
--
--     - In the drop-down, make sure **shared_warehouse** is selected.
--
--     - Then, at the bottom of the pop-up, select **Start and attach**.
--
-- <br></br>
--    <img src="../Includes/images/sql_warehouse.png" alt="SQL Warehouse" width="600">

-- %% [markdown]
-- ## A. Classroom Setup
--
-- Run the following cell to configure your working environment for this notebook.
--
-- **NOTE:** The `DA` object is only used in Databricks Academy courses and is not available outside of these courses. It will dynamically reference the information needed to run the course in the lab environment.
--
-- ### IMPORTANT LAB INFORMATION
--
-- Recall that your lab setup is created with the [0 - REQUIRED - Course Setup]($../0 - REQUIRED - Course Setup and Data Discovery) notebook. If you end your lab session or if your session times out, your environment will be reset, and you will need to rerun the Course Setup notebook.

-- %%
%run ../Includes/1.2-Classroom-Setup

-- %% [markdown]
-- # Use the Catalog Explorer to Answer the Questions Below
--
-- Use the Catalog Explorer to answer the questions below to the best of your ability. This content isn't graded, but is designed to allow you to practice what you learned in this module and explore the Databricks Workspace UI.
--
-- For detailed instructions and the answers, go to the **1.2 Lab Solution** notebook for this lab.

-- %% [markdown]
-- ## B. Explore the `samples` Catalog

-- %% [markdown]
-- 1. Who owns the **samples** catalog?

-- %%
---- Use the Catalog Explorer to find the owner.

-- %%
%skip
-- Question Answer: Databricks, Inc

-- 1. Find the 'samples' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. On the right, under 'About this catalog', notice that the owner of this catalog is 'Databricks, Inc.'.

-- %% [markdown]
-- 2. What permissions do you have on the **samples** catalog?

-- %%
---- Use the Catalog Explorer to find the permissions.

-- %%
%skip
-- Question Answer: None, Permissions cannot be viewed or edited on samples data.

-- 1. Find the 'samples' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'Permissions' tab to view permissions.

-- %% [markdown]
-- 3. How many table(s) are in the **nyctaxi** schema (database) within the **samples** catalog?

-- %%
---- Use the Catalog Explorer to view the tables in the 'nyctaxi' schema.

-- %%
%skip
-- Question Answer: 1 table named 'trips'

-- 1. Find the 'samples' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'nyctaxi' schema.

-- 4. You should see that the 'nyctaxi' schema contains 1 table named 'trips'.

-- %% [markdown]
-- 4. How many columns are in the **samples.nyctaxi.trips** table?

-- %%
---- Use the Catalog Explorer to view the columns in the 'trips' table.

-- %%
%skip
-- Question Answer: 6 columns are in the 'trips' table.

-- 1. Find the 'samples' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'nyctaxi' schema.

-- 4. Select the 'trips' table.

-- 5. View the overview of the table. Here you should see the columns in the table.

-- %% [markdown]
-- ## C. Explore the `dbacademy_ca_sales` Catalog

-- %% [markdown]
-- 1. What two schemas are in the **dbacademy_ca_sales** catalog?

-- %%
---- Use the left navigation bar to view the schemas.

-- %%
%skip
-- Question Answer: 2 schemas, 'information_schema' and 'v01'

-- 1. Find the 'dbacademy_ca_sales' catalog in the left navigation pane.

-- 2. Expand the catalog.

-- 3. View the two schemas within the catalog.

-- %% [markdown]
-- 2. What type is the **dbacademy_ca_sales** catalog?

-- %%
---- Use the Catalog Explorer to view the 'About this catalog' section.

-- %%
%skip
-- Question Answer: Type is 'Delta Sharing' because this catalog was created using Databricks Marketplace when your lab was set up.

-- 1. Find the 'dbacademy_ca_sales' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. In the 'Overview' tab, look at the far right under 'About this catalog'. Notice that the Type is 'Delta Sharing'.

-- %% [markdown]
-- 3. In **dbacademy_ca_sales.v01** navigate to the **customers** table. What permissions do you have on this table?

-- %%
---- Use the Catalog Explorer to view the permissions on the 'customers' table.

-- %%
%skip
-- Question Answer: 'SELECT'

-- 1. Find the 'dbacademy_ca_sales' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'v01' schema.

-- 4. Select the 'customers' table.

-- 5. Select the 'Permissions' tab.

-- %% [markdown]
-- ## D. Explore your Course Schema `dbacademy.labuser_name`

-- %% [markdown]
-- 1. Who created the **dbacademy.labuser_name.ca_orders** table?

-- %%
---- Use the Catalog Explorer to view the Details of the 'ca_orders' table.

-- %%
%skip
-- Question Answer: Table was created by your 'labuser' name (example, 'labuser1234_5678').

-- 1. Find the 'dbacademy' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'labuser_name' schema.

-- 4. Select the 'ca_orders' table.

-- 5. Select the 'Details' tab.

-- 6. Find the row 'Created By'. This table was created by your account using the setup script.

-- %% [markdown]
-- 2. What permissions do you have on your table **ca_orders**?

-- %%
---- Use the Catalog Explorer to view the permissions you have on the 'ca_orders' table.

-- %%
%skip
-- Question Answer: 'ALL PRIVILEGES'

-- 1. Find the 'dbacademy' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'labuser_name' schema.

-- 4. Select the 'ca_orders' table.

-- 5. Select the 'Permissions' tab.

-- 6. Notice that you have 'ALL PRIVILEGES' on this table since you are the owner.

-- %% [markdown]
-- 3. View the history of the **ca_orders** table. What version is this table? What is the most recent **Operation**?

-- %%
---- Use the Catalog Explorer to view the History.

-- %%
%skip
-- Question Answer: 'Version 0', 'CREATE TABLE AS SELECT'

-- 1. Find the 'dbacademy' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'labuser_name' schema.

-- 4. Select the 'ca_orders' table.

-- 5. Select the 'History' tab.

-- 6. Notice that this table has 1 version, 'Version 0', and this table was created using the 'CREATE TABLE AS SELECT' statement.

-- %% [markdown]
-- 4. Add a *AI Suggested Description* to the **ca_orders** table.

-- %%
---- Use the Catalog Explorer to add the 'AI Suggested Description'.

-- %%
%skip
-- Question Answer: Your table should have a description.

-- 1. Find the 'dbacademy' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'labuser_name' schema.

-- 4. Select the 'ca_orders' table.

-- 5. Select the 'Overview' tab.

-- 6. Notice that an 'AI Suggested Description' for the table is available. Select 'Accept'.

-- %% [markdown]
-- 5. View the history of the **ca_orders** How many versions does this table have now? What is the most recent **Operation**?

-- %%
---- Use the Catalog Explorer to view the History.

-- %%
%skip
-- Question Answer: '2 Versions', 'version 0', 'version 1', 'SET TBLPROPERTIES'

-- 1. Find the 'dbacademy' catalog in the left navigation pane.

-- 2. Select the three ellipses to the right of the catalog and select 'Open in Catalog Explorer'.

-- 3. Select the 'labuser_name' schema.

-- 4. Select the 'ca_orders' table.

-- 5. Select the 'History' tab.

-- 6. Notice that this table has '2 versions', 'Version 0' and 'Version 1'. A new version of this table has been added when you added the 'AI generated description' of this table.

-- %% [markdown]
-- &copy; 2025 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
